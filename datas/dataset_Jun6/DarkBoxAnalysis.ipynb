# %% [markdown]
# # Dark Box setup
# Dated Jun 5, 2025
#
#
# Setup:
#
# For the black box
#
# ![image.png](attachment:image.png)
#
# For the DAQ:
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import mplhep as hep
hep.style.use(hep.style.ROOT)

# %% [markdown]
# # Measurement result

# %%
setup1=pd.read_csv("DarkBox/setup1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/setup2.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 channel_consideration="ch1"
#       5 bins_num="auto"
# ----> 7 plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
#       8 plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#       9 plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
#
# NameError: name 'case' is not defined

# %%
setup1=pd.read_csv("DarkBox/setup1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/setup2.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(setup2['ch0'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(1,9000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/Verify1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/Verify2.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(1,9000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/Verify1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/Verify2.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(setup2['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(1,9000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/SiPM1SiPM2.txt",sep=" ")
setup2=pd.read_csv("DarkBox/SiPM2SiPM1.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(setup2['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(1,9000)
plt.legend()
plt.show()
