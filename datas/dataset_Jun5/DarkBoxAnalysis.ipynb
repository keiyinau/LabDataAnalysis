# %% [markdown]
# # Dark Box setup
# Dated Jun 5, 2025
#
#
# Setup:
#
# For the black box
#
# ![image.png](attachment:image.png)
#
# For the DAQ:
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import mplhep as hep
hep.style.use(hep.style.ROOT)

# %% [markdown]
# # Measurement result

# %% [markdown]
# ## H2O

# %%
case="H2O"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
case="H2O"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %% [markdown]
# ## QD

# %%
case="QD"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
case="QD"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %% [markdown]
# ## LAB

# %%
case="LAB"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
case="LAB"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"
plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %% [markdown]
# ## nthLED

# %%
case="nth_LED"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
case="nth_LED"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"
plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %% [markdown]
# ## nthLED Ledon

# %%
case="nth_LedOn"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
case="nth_LedOn"
SiPM1=pd.read_csv("DarkBox/SiPm1_%s.txt"%(case),sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_%s.txt"%(case),sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_%s.txt"%(case),sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %% [markdown]
# ## Empty_LedOn

# %%
SiPM1=pd.read_csv("DarkBox/SiPm1_Empty.txt",sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_Empty.txt",sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_Empty_LedOn.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(SiPM1['ch0'], bins=bins_num,histtype='step',label="SiPM1, %s, count=%.2f"%(case,len(SiPM1['ch0'])))
plt.hist(SiPM2['ch1'], bins=bins_num,histtype='step',label="SiPM2, %s, count=%.2f"%(case,len(SiPM2['ch1'])))
#plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
#plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()

# %%
SiPM1=pd.read_csv("DarkBox/SiPm1_Empty.txt",sep=" ")
SiPM2=pd.read_csv("DarkBox/SiPm2_Empty.txt",sep=" ")
Coincidence=pd.read_csv("DarkBox/SiPm12_Empty_LedOn.txt",sep=" ")
Pedestal=pd.read_csv("DarkBox/0506_pedestal.txt",sep=" ")
channel_consideration="ch1"
bins_num="auto"

plt.hist(Coincidence['ch0'], bins=bins_num,histtype='step',label="Coincidence ch0_20 ch1_20")
plt.hist(Coincidence['ch1'], bins=bins_num,histtype='step',label="Coincidence ch1_20 ch1_20")
plt.hist(Pedestal['ch0'], bins=bins_num,label="Pedestal ch0")
plt.hist(Pedestal['ch1'], bins=bins_num,label="Pedestal ch1")
plt.title("Dark Box Measurement")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,9000)
plt.legend()
plt.show()
