# %% [markdown]
# # Verify Box setup
# Dated Jun 5, 2025
#
#
# Setup:
#
# For the black box
#
# ![image.png](attachment:image.png)
#
# For the DAQ:
#
# ![image-3.png](attachment:image-3.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import mplhep as hep
hep.style.use(hep.style.ROOT)

# %% [markdown]
# # Measurement result

# %% [markdown]
# ## Majority setting

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_30.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_30ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_40.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_40ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_50.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_50ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_60.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_60ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_70.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_70ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_80.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_80ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_90.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_90ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_100.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_100ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_110.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_110ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_120.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_120ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_130.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement Maj_130ns")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/SiPM1SiPM2_Maj_90_1.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/CurrentSetting.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/MajorityWidthSetting/BurstMode.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup1['ch1'], bins=bins_num,histtype='step',label="SiPM2")


#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %% [markdown]
# # Measurement

# %% [markdown]
# ## Blackbox LedOff

# %%
setup1=pd.read_csv("DarkBox/1306_blackbox_sipm1_LedOff.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_blackbox_sipm2_LedOff.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_blackbox_sipm12_LedOff.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/1306_blackbox_sipm1_LedOff.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_blackbox_sipm2_LedOff.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_blackbox_sipm12_LedOff.txt",sep=" ")

bins_num="auto"

plt.hist(setup3['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup3['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %% [markdown]
# ## BlackBox Led on

# %%
setup1=pd.read_csv("DarkBox/1306_blackbox_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_blackbox_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_blackbox_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/1306_blackbox_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_blackbox_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_blackbox_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup3['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup3['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %% [markdown]
# ## LAB

# %%
setup1=pd.read_csv("DarkBox/1306_LAB_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_LAB_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_LAB_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,30000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/1306_LAB_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_LAB_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_LAB_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup3['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup3['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,5000)
plt.ylim(0,50000)
plt.legend()
plt.show()

# %% [markdown]
# ## QD

# %%
setup1=pd.read_csv("DarkBox/1306_QD_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_QD_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_QD_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,12000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/1306_QD_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_QD_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_QD_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup3['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup3['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,12000)
plt.legend()
plt.show()

# %% [markdown]
# ## Empty

# %%
setup1=pd.read_csv("DarkBox/1306_empty_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_empty_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_empty_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %% [markdown]
# ## Water

# %%
setup1=pd.read_csv("DarkBox/1306_water_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_water_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_water_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup1['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup2['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()

# %%
setup1=pd.read_csv("DarkBox/1306_water_sipm1.txt",sep=" ")
setup2=pd.read_csv("DarkBox/1306_water_sipm2.txt",sep=" ")
setup3=pd.read_csv("DarkBox/1306_water_sipm12.txt",sep=" ")

bins_num="auto"

plt.hist(setup3['ch0'], bins=bins_num,histtype='step',label="SiPM1")
plt.hist(setup3['ch1'], bins=bins_num,histtype='step',label="SiPM2")

#plt.hist(ch0_fp['ch0'], bins=bins_num,label=Pedestal ch0)
#plt.hist(ch1_fp['ch1'], bins=bins_num,label=Pedestal ch1)
plt.title("Dark Box Measurement CurrentSetting (~82 ns width)")
plt.xlabel("QDC counts")
plt.ylabel("Counts")
plt.xlim(0,3000)
plt.ylim(0,10000)
plt.legend()
plt.show()
